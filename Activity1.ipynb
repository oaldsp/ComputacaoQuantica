# %% [markdown]
#         Nome: Otávio Pepe
#         RA: 2429853

# %%
from numpy import sqrt
import numpy as np
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram
import math
import cmath

sv=Statevector([1 / sqrt(2), 1j / sqrt(2)])

display(sv.is_valid())
# Out:
# /tmp/ipykernel_12695/3033362885.py:3: DeprecationWarning: Using Qiskit with Python 3.9 is deprecated as of the 2.1.0 release. Support for running Qiskit with Python 3.9 will be removed in the 2.3.0 release, which coincides with when Python 3.9 goes end of life.
#   from qiskit.quantum_info import Statevector
# True

# %%
display(sv.draw("latex"))
# Out:
# $$\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2} i}{2} |1\rangle$$

# %%
stats = sv.sample_counts(1000)
plot_histogram(stats)

# %% [markdown]
# Re-escreva o estado abaixo de modo que a amplitude de |0> seja um valor real.
#
# $\frac{2+i}{3}|0> - \frac{2}{3}|1>$
#
# ==============================================================================
#
# $\frac{2+i}{3}$
#
# Fase -> $arg(2+i) = arctan (1/2)$
#
# $\lambda = e^{-iarctan(1/2)}$
#
# ==============================================================================
#
# $e^{-iarctan(1/2)}*(\frac{2+i}{3}|0> - \frac{2}{3}|1>) = \frac{\sqrt{5}}{3}|0> + (-\frac{4}{3\sqrt{5}}+i\frac{2}{3\sqrt{5}})|1> $

# %%
from qiskit.visualization import plot_bloch_multivector

hw = Statevector([sqrt(5) / 3, -(4/(3*sqrt(5))) + 1j*(2/(3*sqrt(5))) ])

print ("Valido? " + str(hw.is_valid()))
# Out:
# Valido? True

# %%
print("\nLatex:")
display(hw.draw("latex"))
# Out:
# Latex:
# $$\frac{\sqrt{5}}{3} |0\rangle+(-0.596284794 + 0.298142397 i) |1\rangle$$

# %%
print("Esfera de Bloch:")
plot_bloch_multivector(hw)
# Out:
# Esfera de Bloch:

# %%
print("Histograma:")
stats = sv.sample_counts(1000)
plot_histogram(stats)
# Out:
# Histograma:
